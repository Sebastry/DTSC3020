# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebastry/DTSC3020/blob/main/Copy_of_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2
#
# **Course:** DTSC 3020 — Introduction to Computation with Python
# **Lesson:** 2 — Variables, Data Types, Operators
# **Points:** 50 (4 questions)
#
# ---
#
# ## Before you start
#
# Before working on the assignment, make your own copy of the notebook by going to File → Save a copy in Drive. Then complete the assignment in your own copy.
#
#
# ## How to use this notebook
#
# 1. Read each **question** (markdown cell) carefully.
# 2. Write your answer in the **code cell** that follows it.
# 3. Run the cell with `Shift + Enter` to see the output.
# 4. If you get an error, read the message, fix the code, and run it again.
#
#
# ---
# ## How to submit
#
# *You will submit by pushing this notebook to your GitHub account and then pasting the GitHub link in Canvas.*
# In Colab, click **File → Save a copy in GitHub**. Once the notebook is showing on GitHub, click the address bar of your browser and copy the full URL. Paste the link in Canvas.

# %% [markdown]
# ## Question 1 — Variables, Data Types, and Type Conversion  *(12 points)*
#
# Practice creating variables of different types, checking their types, and converting between numeric types.
#
# ### What to do
# 1. Create the following variables:
#    - `course_name` — the text `"DTSC 3020"` *(string)*
#    - `credit_hours` — the whole number `3` *(integer)*
#    - `gpa` — the number `3.75` *(float)*
#    - `is_online` — the value `True` *(boolean)*
# 2. Print each variable **together with its type**, using `type(...)`. Example output line:
#
#    ```
#    DTSC 3020 <class 'str'>
#    ```
#
# 3. Convert `gpa` to an **integer** with `int(...)`, store it in a new variable `gpa_int`, and print it. Then add a **comment** answering: did `int()` round the value or truncate (cut off) the decimal part?
# 4. Use **multiple assignment** to create two variables on one line: `building, room = "Discovery Park", 298`. Then **swap** their values using the one-line swap technique from the lecture, and print them after the swap.
#
# ### Hints
# - `print(course_name, type(course_name))` prints the value and its type on one line.
# - The swap technique: `a, b = b, a`.
# - `int(3.75)` does **not** behave like rounding — run it and see.

# %%
course_name, is_online = "DTSC 3020", True
credit_hours, gpa = 3, 3.75

gpa_int = int(gpa)
# print(gpa_int) does not round up the number to 4, it only takes the integer value of the float number.
# There is the function round(n, x) to round numbers n up to x digits, for instance:
# print(round(gpa)) <<< rounds 3.75 -> 4
# print(round(gpa, 1)) <<< rounds 3.75 -> 3.8

variables = [course_name, is_online, credit_hours, gpa]
for i in variables:
  print(f"{i} is {type(i)}")
# Using "for" function to avoid writing 4 lines of code: print(f"{variable} is {type(variable)}")

credit_hours, gpa = gpa, credit_hours
print(f"\ngpa is now {gpa} and credit_hours is now {credit_hours}")
# \n is an "enter" technique to create a space between outputs
# Out:
# DTSC 3020 is <class 'str'>
# True is <class 'bool'>
# 3 is <class 'int'>
# 3.75 is <class 'float'>
#
# gpa is now 3 and credit_hours is now 3.75

# %% [markdown]
# ## Question 2 — Strings: Indexing, Slicing, and Methods  *(13 points)*
#
# Work with the messy text below and clean it up using the string tools from the lecture.
#
# ### What to do
# The starter variable is provided in the code cell:
#
# ```python
# raw_text = "   data science with PYTHON   "
# ```
#
# 1. Print the **length** of `raw_text` using `len(...)`.
# 2. Create a new variable `clean_text` that has the extra spaces removed (`.strip()`) **and** is all lowercase (`.lower()`). Print it.
# 3. Print the **first character** and the **last character** of `clean_text` using indexing.
# 4. Using **slicing**, print just the word `"data"` from `clean_text`.
# 5. Create a variable `new_text` where the word `"PYTHON"` in `raw_text` is replaced with `"Python 3"` using `.replace(...)`. Print it.
# 6. Finally, use an **f-string** to print one summary sentence, for example:
#
#    ```
#    The cleaned text is 'data science with python' and it has 24 characters.
#    ```
#
#    (Use `len(clean_text)` inside the f-string — don't type the number by hand.)
#
# ### Hints
# - Methods can be chained: `raw_text.strip().lower()`.
# - Indexing: `clean_text[0]` is the first character, `clean_text[-1]` is the last.
# - Slicing: `clean_text[0:4]` gives the first four characters.
# - f-string example: `print(f"It has {len(clean_text)} characters.")`.

# %%
raw_text = "   data science with PYTHON   "
print(f"The raw text is '{raw_text}' and it has {len(raw_text)} characters")
# Prints raw text and its length

clean_text = raw_text.strip().lower()
print(f"\nThe cleaned text is '{clean_text}' and it has {len(clean_text)} characters")
# Prints cleaned text and its length

print(f"\nThe first character is {clean_text[0]} and the last character is {clean_text[-1]}")
print(f"Attempt of using slicing: {clean_text[0:4]}")
# Prints first and last characters of clean text, as well as the word 'data' using slicing.

new_text = raw_text.replace("PYTHON", "Python 3")
print(f"\nThe new text is '{new_text}'")
# Replaces "PYTHON" from raw_text to "Python 3"

# This is fun :)
# Out:
# The raw text is '   data science with PYTHON   ' and it has 30 characters
#
# The cleaned text is 'data science with python' and it has 24 characters
#
# The first character is d and the last character is n
# Attempt of using slicing: data
#
# The new text is '   data science with Python 3   '

# %% [markdown]
# ## Question 3 — Arithmetic, Comparison, Logical, and Membership Operators  *(13 points)*
#
# Use the operator families from the lecture to analyze a student's course results.
#
# ### What to do
# 1. Create these variables:
#    - `earned_points = 43`
#    - `total_points = 50`
#    - `attendance = 0.85`
# 2. **Arithmetic:** Compute `percentage = earned_points / total_points * 100` and print it. Also print `earned_points // 10` (floor division) and `earned_points % 10` (remainder), each labeled so the output is readable.
# 3. **Comparison and logical:** Compute and print these booleans:
#    - `passed = percentage >= 70 and attendance >= 0.80`
#    - `honor  = percentage >= 90 or attendance >= 0.95`
#    - `needs_review = not passed`
# 4. **Assignment operator:** The student earns 5 bonus points. Add them to `earned_points` using `+=`, then print the updated value.
# 5. **Membership:** A list is provided: `topics = ["variables", "strings", "operators"]`. Print the result of `"strings" in topics` and `"loops" not in topics`.
# 6. Add a **comment** at the end answering: in step 3, why is `passed` `True` or `False` for these values? (One short sentence.)
#
# ### Hints
# - Label outputs by passing text first: `print("Percentage:", percentage)`.
# - `and` requires **both** sides to be `True`; `or` requires **at least one**.
# - `points += 5` is shorthand for `points = points + 5`.

# %%
topics = ["variables", "strings", "operators"]
earned_points = 43
total_points = 50
attendance = 0.85

percentage = earned_points / total_points * 100
print(f"Grade: {percentage}%")
print(f"Floor division: {earned_points // 10}")
print(f"Remainder: {earned_points % 10}")

passed = percentage >= 70 and attendance >= 0.80
honor = percentage >= 90 or attendance >= 0.95
needs_review = not passed
print(f"\nPass: {passed}") # True because "percentage" AND "attendance" values are greater than 70 and 0.80 respectively.
print(f"Honor: {honor}") # False because "percentage" is less than 90, and "attendance" value is not greater than 0.95 neither.
print(f"Needs review: {needs_review}") # False because "passed" holds "True", so "needs_review" takes the opposite of True because of -not-

earned_points += 5
percentage = earned_points / total_points * 100
print(f"\nStudent's new score: {earned_points}/{total_points}")
print(f"New grade: {percentage}%")

print("\nIs 'strings' in today's topics?","strings" in topics)
print("Is 'loops' not in today's topics?","loops" not in topics)
# Out:
# Grade: 86.0%
# Floor division: 4
# Remainder: 3
#
# Pass: True
# Honor: False
# Needs review: False
#
# Student's new score: 48/50
# New grade: 96.0%
#
# Is 'strings' in today's topics? True
# Is 'loops' not in today's topics? True

# %% [markdown]
# ## Question 4 — Random Numbers  *(12 points)*
#
# Use Python's `random` module to build a tiny "lucky student" program.
#
# ### What to do
# 1. Import the `random` module.
# 2. Set the seed to your favorite whole number with `random.seed(...)` so your results are **reproducible** (running the cell twice gives the same output).
# 3. Generate and print, with labels:
#    - a random float between 0 and 1 using `random.random()`
#    - a random integer between 1 and 100 using `random.randint(1, 100)`
# 4. A list of students is provided in the code cell. Using that list:
#    - print **one** randomly chosen student with `random.choice(...)`
#    - print **two different** randomly chosen students with `random.sample(..., 2)`
#    - shuffle the whole list with `random.shuffle(...)` and print the shuffled list
# 5. Add a **comment** answering: what does `random.seed(...)` do, and why is it useful? (One or two short sentences.)
#
# ### Hints
# - `random.shuffle(students)` changes the list **in place** — it returns `None`, so shuffle first, then print the list on the next line.
# - Run the cell twice: with a seed set at the top, the output should be identical both times.

# %%
import random
random.seed(73)
# Creates a pseudo-random number generator.
# It is useful to have a reproducible code instead of it having completely different results every time its ran.
students = ["Alice", "Ben", "Carla", "David", "Eva", "Frank"]

print(f"Random number between 0 - 1: {random.random()}")
print(f"Random number between 1 - 100: {random.randint(1, 100)}")
print(f"Randomly chosen student: {random.choice(students)}")
print(f"Two randomly chosen students: {random.sample(students, 2)}")
random.shuffle(students)
print(f"Shuffled list of students: {students}")
# Out:
# Random number between 0 - 1: 0.27981547357298786
# Random number between 1 - 100: 65
# Randomly chosen student: David
# Two randomly chosen students: ['Eva', 'Ben']
# Shuffled list of students: ['Frank', 'Eva', 'Ben', 'Alice', 'Carla', 'David']
